# %% [markdown]
# The sum of numbers:

# %%
n = int(input('Please enter your number. '))
num = []
s=0
for i in range (1,n+1):
 s += i
 num.append(str(i))
adding = " + " .join(num)
print(adding +" = "+ str(s))
